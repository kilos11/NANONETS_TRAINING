# %% [markdown]
# #**How to unapprove a file?**#
# [link text](https://support.nanonets.com/hc/en-us/articles/14280423804305-How-to-unapprove-a-file)

# %% [markdown]
# #**Introduction to Approvals on Nanonets**#
# [link text](https://support.nanonets.com/hc/en-us/articles/10503277564817-Introduction-to-Approvals-on-Nanonets)

# %% [markdown]
# #**Set up Approval Rules**#
# [link text](https://support.nanonets.com/hc/en-us/articles/10503222120849-How-to-set-up-Approval-Rules)

# %% [markdown]
# #**Reviewing files with Approval rules**#
# [link text](https://support.nanonets.com/hc/en-us/articles/4408907825041-Reviewing-files-with-Approval-rules)

# %% [markdown]
# #**Can I mark documents as Rejected?**#
# [link text](https://support.nanonets.com/hc/en-us/articles/8782006269969-Can-I-mark-documents-as-Rejected)

# %% [markdown]
# #**Detect and Flag Duplicate Files**#
# [link text](https://support.nanonets.com/hc/en-us/articles/10701958782993-Detect-and-Flag-Duplicate-Files)

# %% [markdown]
# #**FAQs on Approval Flows**#
# [link text](https://support.nanonets.com/hc/en-us/articles/4408898898577-FAQs-on-Approval-Flows)
