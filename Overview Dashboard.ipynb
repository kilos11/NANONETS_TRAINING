# %% [markdown]
# #**Overview Dashboard: Monitor Your Workflow**#[link text](https://support.nanonets.com/hc/en-us/articles/25081018708497-Overview-Dashboard-Monitor-Your-Workflow)

# %% [markdown]
# #**Create a new summary card**#[link text](https://support.nanonets.com/hc/en-us/articles/25079593446289-Create-a-new-summary-card)
